# %%
import urllib2
from bs4 import BeautifulSoup

# %%
articleURL = "https://timesofindia.indiatimes.com/new-to-canada/immigration-citizenship/Canada-a-home-away-from-home/articleshow/48710982.cms"

# %%
page = urllib2.urlopen(articleURL).read().decode('utf8', 'ignore')
soup = BeautifulSoup(page, "lxml")
soup
# Out:
# <!DOCTYPE HTML>\n<html itemscope="itemscope" itemtype="https://schema.org/NewsArticle" xmlns:dateutil="com.indiatimes.cms.utilities.CMSDateUtility" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#" xmlns:xslthelper="com.times.utils.xslthelper.XMLHelper"><head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article#"><script>\n            function isMobile(){\n                return( function ( a ) {\n\t\t\treturn /(android|bb\\d+|meego).+mobile|avantgo|bada\\/|blackberry|blazer|compal|elaine|fennec|hiptop|iemobile|ip(hone|od)|iris|kindle|lge |maemo|midp|mmp|mobile.+firefox|netfront|opera m(ob|in)i|palm( os)?|phone|p(ixi|re)\\/|plucker|pocket|psp|series(4|6)0|symbian|treo|up\\.(browser|link)|vodafone|wap|windows (ce|phone)|xda|xiino/i.test( a ) || /1207|6310|6590|3gso|4thp|50[1-6]i|770s|802s|a wa|abac|ac(er|oo|s\\-)|ai(ko|rn)|al(av|ca|co)|amoi|an(ex|ny|yw)|aptu|ar(ch|go)|as(te|us)|attw|au(di|\\-m|r |s )|avan|be(ck|ll|nq)|bi(lb|r
# ...

# %%
mydivs = soup.findAll("div", {"class": "Normal"})
mydivs
# Out:
# [<div class="Normal">In the 2010 Karate Kid movie, there is a scene, where a single mother and her son are fighting about moving to a new country. The story begins with a stagnant job market in Detroit, which forces the family to move to China. The young boy is angry about moving away from the only home that he has known all his life. He starts yelling about how he doesn't feel like he belongs in China; he doesn't understand the culture, he gets bullied by kids at school, there is no 24x7 cable or instant hot water showers. In short, he hates it there and just wants to go home! After all the yelling and screaming, a moment comes when his mom replies, "This is home". As someone who has not only lived away from home for the past three years and but also lived in three different countries, watching this scene got me thinking of home. But where was home for me? Was it a place or a feeling? Looking back at my experiences and having spent time in India, Canada and Indonesia, home meant thr
# ...

# %%
soup.find_all('body')
# Out:
# [<body><div id="creative_testing"></div><style>\n\t\t\t\t     .top_strip{margin:0px auto; }\n\t\t\t\t        .bgImg .top_strip{background:0}\n\t\t\t\t        div#content { z-index: 0 !important; position: static !important; background:none !important;}\n\t\t\t\t        @media screen and (min-width: 768px) and (max-width: 999px) {\n\t\t\t\t       .top_strip{display:none;}\n\t\t\t\t   }\n\t\t\t\t</style><input id="isSpolightArticle" type="hidden" value=""/><div class="openinapp_cont movedown" id="openapp"><a href="javascript:void(0)" target="_blank" title="">Open in app</a></div><img class="id_pixelImg hide" src=""/><div class="articleshow" id="container"><div id="content"><div data-article-container="48710982"><div class="articlepage clearfix" data-articlemsid="48710982" data-articleprocess="false" data-articlesec="" data-articleseo="new-to-canada/immigration-citizenship/Canada-a-home-away-from-home" data-isbrandwire="false" data-shorturl="http://toi.in/sBoXWb" data-tweethandle="times
# ...

# %%
soup.findAll(text=True)
# Out:
# [u'HTML',
# ...

# %%
text = ' '.join(map(lambda p: p.text, soup.find_all('body')))
text
# Out:
# u'\n\t\t\t\t     .top_strip{margin:0px auto; }\n\t\t\t\t        .bgImg .top_strip{background:0}\n\t\t\t\t        div#content { z-index: 0 !important; position: static !important; background:none !important;}\n\t\t\t\t        @media screen and (min-width: 768px) and (max-width: 999px) {\n\t\t\t\t       .top_strip{display:none;}\n\t\t\t\t   }\n\t\t\t\tOpen in app+English\u0939\u093f\u0928\u094d\u0926\u0940\u092e\u0930\u093e\u0920\u0940\u09ac\u09be\u0982\u09b2\u09be \u0a97\u0ac1\u0a9c\u0ab0\u0abe\u0aa4\u0ac0\u0c95\u0ca8\u0ccd\u0ca8\u0ca1\u0ba4\u0bae\u0bbf\u0bb4\u0bcd\u0c24\u0c46\u0c32\u0c41\u0c17\u0c41\u0d2e\u0d32\u0d2f\u0d3e\u0d33\u0d02|Epaper|GadgetsNowHI, Edit ProfileMy TimesRedeemLOGOUTSign InVideosTopTrendingCityIndiaEntertainmentBeauty PageantsSportsTVLifestyleHealthFilmfareHumourBusinessTechAutoMusicEventsHindiCityMetro CitiesMumbaiDelhiBangaloreHyderabadKolkataChennaiOther CitiesAgartalaAgraAjmerAmaravatiAhmedabadAllahabadAmritsarAurangabadBareillyBhopalBhubaneswarChandigarhCoim
# ...

# %%
text.encode('ascii', errors='replace').replace("?"," ")
# Out:
# '\n\t\t\t\t     .top_strip{margin:0px auto; }\n\t\t\t\t        .bgImg .top_strip{background:0}\n\t\t\t\t        div#content { z-index: 0 !important; position: static !important; background:none !important;}\n\t\t\t\t        @media screen and (min-width: 768px) and (max-width: 999px) {\n\t\t\t\t       .top_strip{display:none;}\n\t\t\t\t   }\n\t\t\t\tOpen in app+English                                              |Epaper|GadgetsNowHI, Edit ProfileMy TimesRedeemLOGOUTSign InVideosTopTrendingCityIndiaEntertainmentBeauty PageantsSportsTVLifestyleHealthFilmfareHumourBusinessTechAutoMusicEventsHindiCityMetro CitiesMumbaiDelhiBangaloreHyderabadKolkataChennaiOther  MumbaiNoidaPat
# ...

# %%
from bs4.element import Comment

# %%
def tag_visible(element):
    if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
        return False
    if isinstance(element, Comment):
        return False
    return True

# %%
def text_from_html(body):
    soup = BeautifulSoup(body, 'html.parser')
    texts = soup.findAll(text=True)
    visible_texts = filter(tag_visible, texts)  
    return u" ".join(t.strip() for t in visible_texts)

# %%
def text_from_html1(body):
    print(body)
    print
    soup = BeautifulSoup(body, "lxml")
    print(soup)
    texts = soup.findAll(text=True)
    visible_texts = filter(tag_visible, texts)  
    return u" ".join(t.strip() for t in visible_texts)

# %%
def text_from_html2(body):
    soup = BeautifulSoup(body, 'html.parser')
    texts = soup.findAll(text=True)
    mydivs = soup.findAll("div", {"class": "Normal"})
    visible_texts = filter(tag_visible, mydivs)  
    return u" ".join(t.strip() for t in visible_texts)

# %%
# print(text_from_html(page))

onlyText = text_from_html(page)

# onlyText = text_from_html1(mydivs)

# onlyText = text_from_html2(page)

# visible_texts = filter(tag_visible, mydivs)  
# onlyText = u" ".join(t.strip() for t in visible_texts)

print(onlyText)
# Out:
#    Open in app + English हिन्दी मराठी বাংলা ગુજરાતી ಕನ್ನಡ தமிழ் తెలుగు മലയാളം | Epaper | GadgetsNow HI, Edit Profile My Times Redeem LOGOUT Sign In Videos Top Trending City India Entertainment Beauty Pageants Sports TV Lifestyle Health Filmfare Humour Business Tech Auto Music Events Hindi City Metro Cities Mumbai Delhi Bangalore Hyderabad Kolkata Chennai Other Cities Agartala Agra Ajmer Amaravati Ahmedabad Allahabad Amritsar Aurangabad Bareilly Bhopal Bhubaneswar Chandigarh Coimbatore Cuttack Dehradun Erode Faridabad Ghaziabad Goa Gurgaon Guwahati HUBBALLI Imphal Indore Itanagar Jaipur Jammu Jamshedpur Jodhpur Kanpur Kochi Kohima Kolhapur Kozhikode Lucknow Ludhiana Madurai Mangalore Meerut Mysore Nagpur Nashik Navi Mumbai Noida Patna Puducherry Pune Raipur Rajkot Ranchi Srinagar Salem Shillong Shimla Surat Thane Trichy Thiruvananthapuram Udaipur Vadodara Varanasi Vijayawada Visakhapatnam India Maharashtra Delhi Karnataka Tamil Nadu Telangana Uttar Pradesh West Bengal Gujarat Madhya P
# ...

# %%
# finalText = ' '.join(map(lambda p: p.text, soup.find_all('onlyText')))
onlyText.encode('ascii', errors='replace').replace("?"," ")
# Out:
# '   Open in app + English                                                      | Epaper | GadgetsNow HI, Edit Profile My Times Redeem LOGOUT Sign In Videos Top Trending City India Entertainment Beauty Pageants Sports TV Lifestyle Health Filmfare Humour Business Tech Auto Music Events Hindi City Metro Cities Mumbai Delhi Bangalore Hyderabad Kolkata Chennai Other Cities Agartala Agra Ajmer Amaravati Ahmedabad Allahabad Amritsar Aurangabad Bareilly Bhopal Bhubaneswar Chandigarh Coimbatore Cuttack Dehradun Erode Faridabad Ghaziabad Goa Gurgaon Guwahati HUBBALLI Imphal Indore Itanagar Jaipur Jammu Jamshedpur Jodhpur Kanpur Kochi Kohima Kolhapur Kozhikode Lucknow Ludhiana Madurai Mangalore Meerut Mysore Nagpur Nashik Navi Mumbai Noida Patna Puducherry Pune Raipur Rajkot Ranchi Srinagar Salem Shillong Shimla Surat Thane Trichy Thiruvananthapuram Udaipur Vadodara Varanasi Vijayawada Visakhapatnam India Maharashtra Delhi Karnataka Tamil Nadu Telangana Uttar Pradesh West Bengal Gujarat Madhya 
# ...

# %%
import html2text
articleURL = "https://timesofindia.indiatimes.com/new-to-canada/immigration-citizenship/Canada-a-home-away-from-home/articleshow/48710982.cms"
page = urllib2.urlopen(articleURL).read().decode('utf8', 'ignore')
html = open(page).read()
print html2text.html2text(html)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-64-61c1ad0352ae> in <module>()
#       2 articleURL = "https://timesofindia.indiatimes.com/new-to-canada/immigration-citizenship/Canada-a-home-away-from-home/articleshow/48710982.cms"
#       3 page = urllib2.urlopen(articleURL).read().decode('utf8', 'ignore')
# ----> 4 html = open(page).read()
#       5 print html2text.html2text(html)
#
# ...
